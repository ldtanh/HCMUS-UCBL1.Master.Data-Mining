# %%
import pandas
data = pandas.read_csv('top_movies_by_title.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             200 non-null    object
#  1   Studio            200 non-null    object
#  2   Gross             200 non-null    int64
#  3   Gross (Adjusted)  200 non-null    int64
#  4   Year              200 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 7.9+ KB

# %%
data.describe().T
# Out:
#                   count          mean           std          min  \
# Gross             200.0  2.216196e+08  1.441574e+08    9183673.0
# Gross (Adjusted)  200.0  5.041983e+08  2.159814e+08  322261900.0
# Year              200.0  1.986620e+03  2.049355e+01       1921.0
#
#                            25%          50%           75%           max
# Gross             1.087824e+08  200127320.5  3.069535e+08  9.067234e+08
# Gross (Adjusted)  3.677804e+08  438857000.0  5.512131e+08  1.757788e+09
# Year              1.973000e+03       1990.0  2.003250e+03  2.015000e+03

# %%
df = data.groupby('Studio').count().reset_index()
df.columns = ['Studio', 'Count', 'Gross', 'Gross (Adjusted)', 'Year']
df
# Out:
#                      Studio  Count  Gross  Gross (Adjusted)  Year
# 0                      AVCO      1      1                 1     1
# 1      Buena Vista (Disney)     29     29                29    29
# 2                  Columbia     10     10                10    10
# 3                    Disney     11     11                11    11
# 4                Dreamworks      3      3                 3     3
# 5                       Fox     26     26                26    26
# 6                       IFC      1      1                 1     1
# 7                 Lionsgate      3      3                 3     3
# 8                       MGM      7      7                 7     7
# 9                       MPC      1      1                 1     1
# 10                       NM      1      1                 1     1
# 11                 New Line      5      5                 5     5
# 12                    Orion      1      1                 1     1
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns

def hist_count(column, data):
    if column in data:
        f, axes = plt.subplots(1,1,figsize=(15,5))
        sns.countplot(x=column, data=data)
        plt.xticks(rotation = 90)
        plt.suptitle(column, fontsize=20)
        plt.show()
    plt.show()

# %%
for column in ['Year']:
    hist_count(column,data)

# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt

# %%
text = " ".join(review.replace(' ', '_').replace('(', '').replace(')', '') + ',' for review in data.Studio.to_list())
print ("There are {} words in the combination of all review.".format(len(text)))
# Out:
# There are 2218 words in the combination of all review.

# %%
wordcloud = WordCloud(stopwords=[','], max_font_size=50, max_words=100, background_color="white").generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
    pd.set_option('display.max_rows', None)
    pd.set_option('display.max_columns', None)
    pd.set_option('display.width', 2000)
    pd.set_option('display.float_format', '{:20,.2f}'.format)
    pd.set_option('display.max_colwidth', None)
    pd.reset_option('display.max_rows')
    pd.reset_option('display.max_columns')
    pd.reset_option('display.width')
    pd.reset_option('display.float_format')
    pd.reset_option('display.max_colwidth')
pd.set_option('float_format', '{:.2f}'.format)

# %%
data[['Year']].describe().T
# Out:
#       count    mean   std     min     25%     50%     75%     max
# Year 200.00 1986.62 20.49 1921.00 1973.00 1990.00 2003.25 2015.00

# %%
plt.figure(figsize=(10,6))
sns.histplot(data['Year'], bins=100)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Count'>

# %%
sns.set_theme(style="ticks")

sns.pairplot(data)
